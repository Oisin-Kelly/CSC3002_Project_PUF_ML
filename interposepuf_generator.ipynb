# %%
from models.InterposePUF import InterposePUF
from helpers import get_XY, save_to_memmap

# %% [markdown]
# Generating for (1, k)-iPUF

# %%
interpose_puf = InterposePUF(64, 1, 3)

responses = interpose_puf.calculate_responses_with_random_challenges(400_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/1_3iPUF_chal_400000.memmap")
save_to_memmap(Y, "crps/interpose_puf/1_3iPUF_resp_400000.memmap")

# %%
interpose_puf = InterposePUF(64, 1, 4)

responses = interpose_puf.calculate_responses_with_random_challenges(400_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/1_4iPUF_chal_400000.memmap")
save_to_memmap(Y, "crps/interpose_puf/1_4iPUF_resp_400000.memmap")

# %%
interpose_puf = InterposePUF(64, 1, 5)

responses = interpose_puf.calculate_responses_with_random_challenges(800_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/1_5iPUF_chal_800000.memmap")
save_to_memmap(Y, "crps/interpose_puf/1_5iPUF_resp_800000.memmap")

# %%
interpose_puf = InterposePUF(64, 1, 6)

responses = interpose_puf.calculate_responses_with_random_challenges(5_000_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/1_6iPUF_chal_5000000.memmap")
save_to_memmap(Y, "crps/interpose_puf/1_6iPUF_resp_5000000.memmap")

# %%
interpose_puf = InterposePUF(64, 1, 7)

responses = interpose_puf.calculate_responses_with_random_challenges(10_000_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/1_7iPUF_chal_10000000.memmap")
save_to_memmap(Y, "crps/interpose_puf/1_7iPUF_resp_10000000.memmap")

# %% [markdown]
# Generating for (k, k)-iPUF

# %%
interpose_puf = InterposePUF(64, 3, 3)

responses = interpose_puf.calculate_responses_with_random_challenges(400_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/3_3iPUF_chal_400000.memmap")
save_to_memmap(Y, "crps/interpose_puf/3_3iPUF_resp_400000.memmap")

# %%
interpose_puf = InterposePUF(64, 4, 4)

responses = interpose_puf.calculate_responses_with_random_challenges(1_000_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/4_4iPUF_chal_1000000.memmap")
save_to_memmap(Y, "crps/interpose_puf/4_4iPUF_resp_1000000.memmap")

# %%
interpose_puf = InterposePUF(64, 5, 5)

responses = interpose_puf.calculate_responses_with_random_challenges(10_000_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/5_5iPUF_chal_10000000.memmap")
save_to_memmap(Y, "crps/interpose_puf/5_5iPUF_resp_10000000.memmap")

# %%
interpose_puf = InterposePUF(64, 6, 6)

responses = interpose_puf.calculate_responses_with_random_challenges(20_000_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/6_6iPUF_chal_20000000.memmap")
save_to_memmap(Y, "crps/interpose_puf/6_6iPUF_resp_20000000.memmap")

# %%
interpose_puf = InterposePUF(64, 7, 7)

responses = interpose_puf.calculate_responses_with_random_challenges(40_000_000)

X, Y = get_XY(responses)

save_to_memmap(X, "crps/interpose_puf/7_7iPUF_chal_40000000.memmap")
save_to_memmap(Y, "crps/interpose_puf/7_7iPUF_resp_40000000.memmap")
