# %%
from models.XorPUF import XorPUF
from helpers import get_XY, save_to_memmap
import os

# %% [markdown]
# Creating folders

# %%
os.makedirs("crps/xor_puf/0noise", exist_ok=True)
os.makedirs("crps/xor_puf/5noise", exist_ok=True)
os.makedirs("crps/xor_puf/10noise", exist_ok=True)
os.makedirs("crps/xor_puf/20noise", exist_ok=True)
os.makedirs("crps/xor_puf/20noise_majority", exist_ok=True)

# %% [markdown]
# Generating (4-9)XOR PUF (0% noise)

# %%
# 4 streams
xor_puf = XorPUF(64, 4, noise=0.00)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/0noise/4XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/0noise/4XOR_64bit_resp_1000000.memmap")

# 5 streams
xor_puf = XorPUF(64, 5, noise=0.00)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/0noise/5XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/0noise/5XOR_64bit_resp_1000000.memmap")

# 6 streams
xor_puf = XorPUF(64, 6, noise=0.00)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/0noise/6XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/0noise/6XOR_64bit_resp_2000000.memmap")

# 7 streams
xor_puf = XorPUF(64, 7, noise=0.00)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/0noise/7XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/0noise/7XOR_64bit_resp_2000000.memmap")

# 8 streams
xor_puf = XorPUF(64, 8, noise=0.00)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/0noise/8XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/0noise/8XOR_64bit_resp_5000000.memmap")

# 9 streams
xor_puf = XorPUF(64, 9, noise=0.00)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/0noise/9XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/0noise/9XOR_64bit_resp_5000000.memmap")
# Out:
# for 42 it is [-0.250919762305275, 0.9014286128198323, 0.4639878836228102, 0.1973169683940732, -0.687962719115127, -0.6880109593275947, -0.8838327756636011, 0.7323522915498704, 0.2022300234864176, 0.416145155592091, -0.9588310114083951, 0.9398197043239886, 0.6648852816008435, -0.5753217786434477, -0.6363500655857988, -0.6331909802931324, -0.39151551408092455, 0.04951286326447568, -0.13610996271576847, -0.4175417196039162, 0.22370578944475894, -0.7210122786959163, -0.4157107029295637, -0.2672763134126166, -0.08786003156592814, 0.5703519227860272, -0.6006524356832805, 0.02846887682722321, 0.18482913772408494, -0.9070991745600046, 0.21508970380287673, -0.6589517526254169, -0.869896814029441, 0.8977710745066665, 0.9312640661491187, 0.6167946962329223, -0.39077246165325863, -0.8046557719872323, 0.3684660530243138, -0.1196950125207974, -0.7559235303104423, -0.00964617977745963, -0.9312229577695632, 0.8186408041575641, -0.48244003679996617, 0.32504456870796394, -0.3765778478211781, 0.0401360
# ...

# %% [markdown]
# Generating (4-9)XOR PUF (5% noise)

# %%
# 4 streams
xor_puf = XorPUF(64, 4, noise=0.05)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/5noise/4XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/5noise/4XOR_64bit_resp_1000000.memmap")

# 5 streams
xor_puf = XorPUF(64, 5, noise=0.05)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/5noise/5XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/5noise/5XOR_64bit_resp_1000000.memmap")

# 6 streams
xor_puf = XorPUF(64, 6, noise=0.05)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/5noise/6XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/5noise/6XOR_64bit_resp_2000000.memmap")

# 7 streams
xor_puf = XorPUF(64, 7, noise=0.05)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/5noise/7XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/5noise/7XOR_64bit_resp_2000000.memmap")

# 8 streams
xor_puf = XorPUF(64, 8, noise=0.05)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/5noise/8XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/5noise/8XOR_64bit_resp_5000000.memmap")

# 9 streams
xor_puf = XorPUF(64, 9, noise=0.05)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/5noise/9XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/5noise/9XOR_64bit_resp_5000000.memmap")
# Out:
# for 42 it is [-0.250919762305275, 0.9014286128198323, 0.4639878836228102, 0.1973169683940732, -0.687962719115127, -0.6880109593275947, -0.8838327756636011, 0.7323522915498704, 0.2022300234864176, 0.416145155592091, -0.9588310114083951, 0.9398197043239886, 0.6648852816008435, -0.5753217786434477, -0.6363500655857988, -0.6331909802931324, -0.39151551408092455, 0.04951286326447568, -0.13610996271576847, -0.4175417196039162, 0.22370578944475894, -0.7210122786959163, -0.4157107029295637, -0.2672763134126166, -0.08786003156592814, 0.5703519227860272, -0.6006524356832805, 0.02846887682722321, 0.18482913772408494, -0.9070991745600046, 0.21508970380287673, -0.6589517526254169, -0.869896814029441, 0.8977710745066665, 0.9312640661491187, 0.6167946962329223, -0.39077246165325863, -0.8046557719872323, 0.3684660530243138, -0.1196950125207974, -0.7559235303104423, -0.00964617977745963, -0.9312229577695632, 0.8186408041575641, -0.48244003679996617, 0.32504456870796394, -0.3765778478211781, 0.0401360
# ...

# %% [markdown]
# Generating (4-9)XOR PUF (10% noise)

# %%
# 4 streams
xor_puf = XorPUF(64, 4, noise=0.10)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/10noise/4XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/10noise/4XOR_64bit_resp_1000000.memmap")

# 5 streams
xor_puf = XorPUF(64, 5, noise=0.10)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/10noise/5XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/10noise/5XOR_64bit_resp_1000000.memmap")

# 6 streams
xor_puf = XorPUF(64, 6, noise=0.10)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/10noise/6XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/10noise/6XOR_64bit_resp_2000000.memmap")

# 7 streams
xor_puf = XorPUF(64, 7, noise=0.10)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/10noise/7XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/10noise/7XOR_64bit_resp_2000000.memmap")

# 8 streams
xor_puf = XorPUF(64, 8, noise=0.10)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/10noise/8XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/10noise/8XOR_64bit_resp_5000000.memmap")

# 9 streams
xor_puf = XorPUF(64, 9, noise=0.10)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/10noise/9XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/10noise/9XOR_64bit_resp_5000000.memmap")
# Out:
# for 42 it is [-0.250919762305275, 0.9014286128198323, 0.4639878836228102, 0.1973169683940732, -0.687962719115127, -0.6880109593275947, -0.8838327756636011, 0.7323522915498704, 0.2022300234864176, 0.416145155592091, -0.9588310114083951, 0.9398197043239886, 0.6648852816008435, -0.5753217786434477, -0.6363500655857988, -0.6331909802931324, -0.39151551408092455, 0.04951286326447568, -0.13610996271576847, -0.4175417196039162, 0.22370578944475894, -0.7210122786959163, -0.4157107029295637, -0.2672763134126166, -0.08786003156592814, 0.5703519227860272, -0.6006524356832805, 0.02846887682722321, 0.18482913772408494, -0.9070991745600046, 0.21508970380287673, -0.6589517526254169, -0.869896814029441, 0.8977710745066665, 0.9312640661491187, 0.6167946962329223, -0.39077246165325863, -0.8046557719872323, 0.3684660530243138, -0.1196950125207974, -0.7559235303104423, -0.00964617977745963, -0.9312229577695632, 0.8186408041575641, -0.48244003679996617, 0.32504456870796394, -0.3765778478211781, 0.0401360
# ...

# %% [markdown]
# Generating (4-9)XOR PUF (20% noise)

# %%
# 4 streams
xor_puf = XorPUF(64, 4, noise=0.20)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise/4XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise/4XOR_64bit_resp_1000000.memmap")

# 5 streams
xor_puf = XorPUF(64, 5, noise=0.20)

responses = xor_puf.calculate_responses_with_random_challenges(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise/5XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise/5XOR_64bit_resp_1000000.memmap")

# 6 streams
xor_puf = XorPUF(64, 6, noise=0.20)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise/6XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise/6XOR_64bit_resp_2000000.memmap")

# 7 streams
xor_puf = XorPUF(64, 7, noise=0.20)

responses = xor_puf.calculate_responses_with_random_challenges(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise/7XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise/7XOR_64bit_resp_2000000.memmap")

# 8 streams
xor_puf = XorPUF(64, 8, noise=0.20)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise/8XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise/8XOR_64bit_resp_5000000.memmap")

# 9 streams
xor_puf = XorPUF(64, 9, noise=0.20)

responses = xor_puf.calculate_responses_with_random_challenges(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise/9XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise/9XOR_64bit_resp_5000000.memmap")
# Out:
# for 42 it is [-0.250919762305275, 0.9014286128198323, 0.4639878836228102, 0.1973169683940732, -0.687962719115127, -0.6880109593275947, -0.8838327756636011, 0.7323522915498704, 0.2022300234864176, 0.416145155592091, -0.9588310114083951, 0.9398197043239886, 0.6648852816008435, -0.5753217786434477, -0.6363500655857988, -0.6331909802931324, -0.39151551408092455, 0.04951286326447568, -0.13610996271576847, -0.4175417196039162, 0.22370578944475894, -0.7210122786959163, -0.4157107029295637, -0.2672763134126166, -0.08786003156592814, 0.5703519227860272, -0.6006524356832805, 0.02846887682722321, 0.18482913772408494, -0.9070991745600046, 0.21508970380287673, -0.6589517526254169, -0.869896814029441, 0.8977710745066665, 0.9312640661491187, 0.6167946962329223, -0.39077246165325863, -0.8046557719872323, 0.3684660530243138, -0.1196950125207974, -0.7559235303104423, -0.00964617977745963, -0.9312229577695632, 0.8186408041575641, -0.48244003679996617, 0.32504456870796394, -0.3765778478211781, 0.0401360
# ...

# %% [markdown]
# Generating (4-9)XOR PUF (20% noise with majority vote)

# %%
# 4 streams
xor_puf = XorPUF(64, 4, noise=0.20)

responses = xor_puf.majority_vote(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise_majority/4XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise_majority/4XOR_64bit_resp_1000000.memmap")

# 5 streams
xor_puf = XorPUF(64, 5, noise=0.20)

responses = xor_puf.majority_vote(1_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise_majority/5XOR_64bit_chal_1000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise_majority/5XOR_64bit_resp_1000000.memmap")

# 6 streams
xor_puf = XorPUF(64, 6, noise=0.20)

responses = xor_puf.majority_vote(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise_majority/6XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise_majority/6XOR_64bit_resp_2000000.memmap")

# 7 streams
xor_puf = XorPUF(64, 7, noise=0.20)

responses = xor_puf.majority_vote(2_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise_majority/7XOR_64bit_chal_2000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise_majority/7XOR_64bit_resp_2000000.memmap")

# 8 streams
xor_puf = XorPUF(64, 8, noise=0.20)

responses = xor_puf.majority_vote(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise_majority/8XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise_majority/8XOR_64bit_resp_5000000.memmap")

# 9 streams
xor_puf = XorPUF(64, 9, noise=0.20)

responses = xor_puf.majority_vote(5_000_000)

challenges, responses = get_XY(responses)

save_to_memmap(challenges, "crps/xor_puf/20noise_majority/9XOR_64bit_chal_5000000.memmap")
save_to_memmap(responses, "crps/xor_puf/20noise_majority/9XOR_64bit_resp_5000000.memmap")
# Out:
# for 42 it is [-0.250919762305275, 0.9014286128198323, 0.4639878836228102, 0.1973169683940732, -0.687962719115127, -0.6880109593275947, -0.8838327756636011, 0.7323522915498704, 0.2022300234864176, 0.416145155592091, -0.9588310114083951, 0.9398197043239886, 0.6648852816008435, -0.5753217786434477, -0.6363500655857988, -0.6331909802931324, -0.39151551408092455, 0.04951286326447568, -0.13610996271576847, -0.4175417196039162, 0.22370578944475894, -0.7210122786959163, -0.4157107029295637, -0.2672763134126166, -0.08786003156592814, 0.5703519227860272, -0.6006524356832805, 0.02846887682722321, 0.18482913772408494, -0.9070991745600046, 0.21508970380287673, -0.6589517526254169, -0.869896814029441, 0.8977710745066665, 0.9312640661491187, 0.6167946962329223, -0.39077246165325863, -0.8046557719872323, 0.3684660530243138, -0.1196950125207974, -0.7559235303104423, -0.00964617977745963, -0.9312229577695632, 0.8186408041575641, -0.48244003679996617, 0.32504456870796394, -0.3765778478211781, 0.0401360
# ...
